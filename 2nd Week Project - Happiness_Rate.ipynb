# %% [markdown]
# <b> Objective : To get Happiness Rate and correlation between vaious Factors

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Pulling and reading the data from file
df=pd.read_csv('hap_report.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# First 10 head count from the file
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# ----

# %% [markdown]
# From the given data I will be dropping Rank, Country and region data from the table as its not useful for overall prediction because in new set of data we might get new rank , country or region. Hence, we will focus more on Numeric data column values for better prediction.

# %%
df.drop(['Country','Region','Happiness Rank'],axis=1,inplace=True )

# %%
df.head(10)
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
# 5            7.406         0.03140                   1.29025  1.31826
# 6            7.378         0.02799                   1.32944  1.28017
# 7            7.364         0.03157                   1.33171  1.28907
# 8            7.286         0.03371                   1.25018  1.31967
# 9            7.284         0.04083                   1.33358  1.30923
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# ...

# %% [markdown]
# <b> Visualisation of Data

# %%
#Visualisation using seaborn and matplotlib to understand the column correlation
plt.figure(figsize=(14, 12))
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# Here Happiness Score is mostly correlated to GDP , Family and Health and least correlated to Governmnent and
# Generosity

# %% [markdown]
# ---

# %% [markdown]
# <b> Preprocessing

# %%
#checking missing Values
df.isnull().sum()
# Clean dataset with no null Value
# Out:
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.dtypes
# Out:
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# Scaling
y=df['Happiness Score']
x=df.drop('Happiness Score',axis=1)

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 153         0.03464                   0.22208  0.77370
# 154         0.03656                   0.28665  0.35386
# 155         0.05015                   0.66320  0.47489
# 156         0.08658                   0.01530  0.41587
# 157         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %% [markdown]
# <b> Linear Regression Model

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Scaling x-axis because its the value on which value of y-axis (happiness score) depends
scaler = MinMaxScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0          0.131954                  0.826132  0.962403
# 1          0.256311                  0.770412  1.000000
# 2          0.124947                  0.784113  0.970297
# 3          0.171549                  0.863099  0.949167
# 4          0.143943                  0.784592  0.943219
# ..              ...                       ...       ...
# 153        0.136429                  0.131376  0.551764
# 154        0.152638                  0.169573  0.252355
# 155        0.267370                  0.392329  0.338668
# 156        0.574926                  0.009051  0.296578
# 157        0.411904                  0.123449  0.099805
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    0.918244  0.993789                       0.760595
# 1                    0.924496  0.938841                       0.256292
# 2                    0.853099  0.969615                       0.876175
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,train_size=0.7)

# %%
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print (model.score(X_test,y_test))
# Out:
# 0.9999999101071803
